# %% [markdown]
# ### Giving Computers the Ability to Learn from Data

# %% [markdown]
# In this section, we'll take a look at the three types of Machine Learning.
#
# - **Supervised Learning**
#   - labeled data
#   - direkt feedback
#   - predict future
# - **Unsupervised Learning**
#   -  no labels and feedback
#   - find hidden str. in data
# - **Reinforcement Learning**
#   - reward system

# %% [markdown]
# - **Supervised Learning** : training examples(inputs) and desired outputs labels are already known.
# - **Classification for predicting class labels** : labels are dicrete/unordered values that can be understood as the group membership of the ins.
#
# ![image.png](attachment:2622033f-7012-47f4-af53-9e1d15cec2aa.png)
#
# the figure illustrates the concept of **binary classification** task given 30 training examples (15 examples are negative / 15 examples are positive) In this scenaria is *two-dimensional* /two categories.
#
# - **Reinforcement Learning** : is to develop a system that improves its performance based on interactions with the environment. Win or Lose
# - **Regression Analysis** : we are given a number of predictoor variables and a outcome, then we try to find a relationship between those variables that allows us to predict an outcome.
# - **Unsupervised Learning**
# - **Clustering** : exploratory data analysis tech. that allows us to organize a information into meaningful clusters  without having any prior knoledge of their groups membership.
# - **Dimensionaly Reduction** : we are workin with data of high number of measurements that can present a challange for limited space. DR is a commonly used approach in the future preprocessingg to remove noise data. Sometimes, DR can also be useful for visalizing data...

# %% [markdown]
# **ML Terminology**
# - Training Example : a row in a table representing the dataset and synonymous
# - Training : model fitting
# - Feature : a column in a data tavle or data matrix
# - Target : synonymous with outcome
# - Loss Function : synonymously with a cost function, sometimes, it is called an error functtion
#
# **A ROADMAP FOR ML**
#
# *Preprocessing - Learning - Evaluation - Prediction*
